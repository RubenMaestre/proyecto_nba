# %%
import numpy as np
import pandas as pd
import os

import requests
from  bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.by import By

from time import sleep
import random

# %%
# Vamos a entrar con selenium a la página oficial de la NBA.
# Si entramos desde España directamente a www.nba.com, nos redirecciona a una web oficial en español, por ello entramos a nba.com/games

chrome_driver = "chromedriver.exe"

browser = webdriver.Chrome()

browser.get("https://nba.com/games")

browser.maximize_window()

# Vamos a aceptar la política de cookies / privacidad con selenium.
# Vamos a ponerle que espere un segundo una vez que cargue todo correctamente antes de dar aceptar.

sleep(1)
browser.find_element(by=By.ID, value="onetrust-accept-btn-handler").click()

# Lo primero que queremos hacer es acceder a la página de estadísticas de los jugadores, por ello, a través de selenium vamos a ir a ese sitio específico

sleep(2)
browser.find_element(by=By.XPATH, value="//span[contains(text(), 'Players')]").click()

# Una vez estamos en la página de players, queremos que nos liste todos los jugadores que hay en la NBA esta temporada

seleccion_menu = browser.find_element(by=By.CSS_SELECTOR, value=".DropDown_select__4pIg9")
sleep(0.3)
seleccion_menu_all = browser.find_element(by=By.CSS_SELECTOR, value="#__next > div.Layout_base__6IeUC.Layout_justNav__2H4H0.Layout_withSubNav__ByKRF > div.Layout_mainContent__jXliI > main > div.MaxWidthContainer_mwc__ID5AG > section > div > div.PlayerList_content__kwT7z > div.PlayerList_filters__n_6IL > div.PlayerList_pagination__c5ijE > div > div.Pagination_pageDropdown__KgjBU > div > label > div > select > option:nth-child(1)").click()

# %%
# Ahora ya tenemos listado 542 filas. Vamos a empezar con el webscreaping
# Lo primero que tenemos que hacer es darle a bs4 la página que quiere hacer scraping, para ello vamos a preguntar a selenium cual es el html:

web_jugadores = browser.page_source

# A partir de ahí vamos con bs4

soup = BeautifulSoup(web_jugadores, "html.parser")

# Y ahora vamos a buscar todos los enlaces que hay en la página de los jugadores. Para ello utilizamos un bucle con la clase Anchor... para guardarlos en una variable

urls_jugadores_nba = [a["href"] for a in soup.find_all("a", class_="Anchor_anchor__cSc3P RosterRow_playerLink__qw1vG")]

# %%
print(urls_jugadores_nba)
# Out:
# ['/player/1630173/precious-achiuwa/', '/player/203500/steven-adams/', '/player/1628389/bam-adebayo/', '/player/1630534/ochai-agbaji/', '/player/1630583/santi-aldama/', '/player/1629638/nickeil-alexander-walker/', '/player/1628960/grayson-allen/', '/player/1628386/jarrett-allen/', '/player/1630631/jose-alvarado/', '/player/203937/kyle-anderson/', '/player/203507/giannis-antetokounmpo/', '/player/203648/thanasis-antetokounmpo/', '/player/1630175/cole-anthony/', '/player/1628384/og-anunoby/', '/player/1627853/ryan-arcidiacono/', '/player/1630166/deni-avdija/', '/player/1629028/deandre-ayton/', '/player/1628962/udoka-azubuike/', '/player/1630641/ibou-badji/', '/player/1628963/marvin-bagley-iii/', '/player/1641735/amari-bailey/', '/player/1631116/patrick-baldwin-jr/', '/player/1630163/lamelo-ball/', '/player/1628366/lonzo-ball/', '/player/1628964/mo-bamba/', '/player/1631094/paolo-banchero/', '/player/1630217/desmond-bane/', '/player/1630625/dalano-banton/', '/player/1631230/dominick-barlow/', '/player/203084/harrison-barnes/', '/player/1630567/scottie-barnes/', '/player/1629628/rj-barrett/', '/player/1629646/charles-bassey/', '/player/1641734/emoni-bates/', '/player/1628966/keita-bates-diop/', '/player/201587/nicolas-batum/', '/player/203078/bradley-beal/', '/player/1627736/malik-beasley/', '/player/1630699/marjon-beauchamp/', '/player/1631262/jules-bernard/', '/player/202722/davis-bertans/', '/player/201976/patrick-beverley/', '/player/1630180/saddiq-bey/', '/player/1629048/goga-bitadze/', '/player/1641931/onuralp-bitim/', '/player/202687/bismack-biyombo/', '/player/1641710/anthony-black/', '/player/1641778/leaky-black/', '/player/203992/bogdan-bogdanovic/', '/player/202711/bojan-bogdanovic/', '/player/1629626/bol-bol/', '/player/1629716/marques-bolden/', '/player/1626164/devin-booker/', '/player/1630527/brandon-boston-jr/', '/player/1628449/chris-boucher/', '/player/1630547/james-bouknight/', '/player/1631123/jamaree-bouyea/', '/player/1631103/malaki-branham/', '/player/1631128/christian-braun/', '/player/1628969/mikal-bridges/', '/player/1628970/miles-bridges/', '/player/1629052/oshae-brissett/', '/player/1627763/malcolm-brogdon/', '/player/1629717/armoni-brooks/', '/player/1628415/dillon-brooks/', '/player/1628971/bruce-brown/', '/player/1627759/jaylen-brown/', '/player/1631112/kendall-brown/', '/player/1641738/kobe-brown/', '/player/1629650/moses-brown/', '/player/1630535/greg-brown-iii/', '/player/1629718/charlie-brown-jr/', '/player/1628972/troy-brown-jr/', '/player/1628973/jalen-brunson/', '/player/1628418/thomas-bryant/', '/player/1641723/kobe-bufkin/', '/player/203493/reggie-bullock-jr/', '/player/202692/alec-burks/', '/player/1630215/jared-butler/', '/player/202710/jimmy-butler/', '/player/1631288/jamal-cain/', '/player/203484/kentavious-caldwell-pope/', '/player/1641739/toumani-camara/', '/player/1628427/vlatko-cancar/', '/player/203991/clint-capela/', '/player/1628975/jevon-carter/', '/player/1628976/wendell-carter-jr/', '/player/1627936/alex-caruso/', '/player/1630658/colin-castleton/', '/player/1630608/malcolm-cazalon/', '/player/1630577/julian-champagnie/', '/player/1631108/max-christie/', '/player/1631321/sidy-cissoko/', '/player/1641740/jaylen-clark/', '/player/1629634/brandon-clarke/', '/player/203903/jordan-clarkson/', '/player/1629651/nic-claxton/', '/player/1641730/noah-clowney/', '/player/1629599/amir-coffey/', '/player/1628381/john-collins/', '/player/1628380/zach-collins/', '/player/201144/mike-conley/', '/player/1626192/pat-connaughton/', '/player/1641731/bilal-coulibaly/', '/player/1641741/ricky-council-iv/', '/player/203496/robert-covington/', '/player/1628470/torrey-craig/', '/player/203109/jae-crowder/', '/player/1630595/cade-cunningham/', '/player/203552/seth-curry/', '/player/201939/stephen-curry/', '/player/1630700/dyson-daniels/', '/player/203076/anthony-davis/', '/player/1631098/johnny-davis/', '/player/1631120/jd-davison/', '/player/201942/demar-derozan/', '/player/1641926/dexter-dennis/', '/pla ...

# %%
# Al intentar acceder a los jugadores, nos hemos dado cuenta que nos daba un error por no tener la ruta completa. Así que vamos a añadirla antes de continuar:

url_base = "https://www.nba.com"
urls_jugadores_nba = [url_base + a["href"] for a in soup.find_all("a", class_="Anchor_anchor__cSc3P RosterRow_playerLink__qw1vG")]

# Solucionado este problema, ahora vamos a acceder a cada uno de los jugadores
response = requests.get(urls_jugadores_nba[0])

soup = BeautifulSoup(response.text, "html.parser")

# %%
def extraer_informacion_jugador(soup,url):
    id_jugador = url.split('/')[-3]
    elementos_nombre = soup.select(".PlayerSummary_playerNameText___MhqC")
    nombre = elementos_nombre[0].get_text() if len(elementos_nombre) >= 2 else "none"
    apellido = elementos_nombre[1].get_text() if len(elementos_nombre) >= 2 else "none"

    equipo_dorsal_posicion = soup.find("p", class_="PlayerSummary_mainInnerInfo__jv3LO")
    if equipo_dorsal_posicion:
        equipo_dorsal_posicion = equipo_dorsal_posicion.get_text()
        partes = equipo_dorsal_posicion.split('|')
        equipo = partes[0].strip() if len(partes) > 0 else "none"
        dorsal = partes[1].strip() if len(partes) > 1 else "none"
        posicion = partes[2].strip() if len(partes) > 2 else "none"
    else:
        equipo = dorsal = posicion = ""
   
    
    datos_varios = soup.find_all("p", class_="PlayerSummary_playerStatValue___EDg_")
    ppg = datos_varios[0].get_text() if len(datos_varios) > 0 else "none"
    rpg = datos_varios[1].get_text() if len(datos_varios) > 1 else "none"
    apg = datos_varios[2].get_text() if len(datos_varios) > 2 else "none"
    pie = datos_varios[3].get_text() if len(datos_varios) > 3 else "none"

    detalles = [p.get_text() for p in soup.find_all("p", class_="PlayerSummary_playerInfoValue__JS8_v")]
    altura = detalles[0] if len(detalles) > 0 else "none"
    peso = detalles[1] if len(detalles) > 1 else "none"
    pais = detalles[2] if len(detalles) > 2 else "none"
    ultimo_equipo = detalles[3] if len(detalles) > 3 else "none"
    edad = detalles[4] if len(detalles) > 4 else "none"
    cumpleaños = detalles[5] if len(detalles) > 5 else "none"
    draft = detalles[6] if len(detalles) > 6 else "none"
    experiencia = detalles[7] if len(detalles) > 7 else "none"

    return {
        "id_jugador": id_jugador,
        "nombre": nombre,
        "apellido": apellido,
        "equipo": equipo,
        "dorsal": dorsal,
        "posicion": posicion,
        "ppg": ppg,
        "rpg": rpg,
        "apg": apg,
        "pie": pie,
        "altura": altura,
        "peso": peso,
        "pais": pais,
        "ultimo_equipo": ultimo_equipo,
        "edad": edad,
        "cumpleaños": cumpleaños,
        "draft": draft,
        "experiencia": experiencia
    }

# %%
id_jugador, nombre, apellido, equipo, dorsal, posicion, ppg, rpg, apg, pie, altura, peso, pais, ultimo_equipo, edad, cumpleaños, draft, experiencia = [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []

# %%
for url in urls_jugadores_nba:
    print(url)
    
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")

    # Para extraer la información de los jugadores vamos a utilizar la función que definimos la de "extraer_informacion_jugador"
    info_jugador = extraer_informacion_jugador(soup,url)

    # Y ahora vamos a agregar toda esa información utilizando un append a la lista
    id_jugador.append(info_jugador['id_jugador'])
    nombre.append(info_jugador['nombre'])
    apellido.append(info_jugador['apellido'])
    equipo.append(info_jugador['equipo'])
    dorsal.append(info_jugador['dorsal'])
    posicion.append(info_jugador['posicion'])
    ppg.append(info_jugador['ppg'])
    rpg.append(info_jugador['rpg'])
    apg.append(info_jugador['apg'])
    pie.append(info_jugador['pie'])
    altura.append(info_jugador['altura'])
    peso.append(info_jugador['peso'])
    pais.append(info_jugador['pais'])
    ultimo_equipo.append(info_jugador['ultimo_equipo'])
    edad.append(info_jugador['edad'])
    cumpleaños.append(info_jugador['cumpleaños'])
    draft.append(info_jugador['draft'])
    experiencia.append(info_jugador['experiencia'])
    
    # Para intentar que el servidor no nos bloquee, vamos a introducir un rango aleatorio entre
    # 3 y 10 segundos para hacer peticiones, igual es mucho, pero con menos nos ha bloqueado la web de la NBA
    tiempo_espera = random.uniform(3, 10)
    sleep(tiempo_espera)
# Out:
# https://www.nba.com/player/1630173/precious-achiuwa/
# https://www.nba.com/player/203500/steven-adams/
# https://www.nba.com/player/1628389/bam-adebayo/
# https://www.nba.com/player/1630534/ochai-agbaji/
# https://www.nba.com/player/1630583/santi-aldama/
# https://www.nba.com/player/1629638/nickeil-alexander-walker/
# https://www.nba.com/player/1628960/grayson-allen/
# https://www.nba.com/player/1628386/jarrett-allen/
# https://www.nba.com/player/1630631/jose-alvarado/
# https://www.nba.com/player/203937/kyle-anderson/
# https://www.nba.com/player/203507/giannis-antetokounmpo/
# https://www.nba.com/player/203648/thanasis-antetokounmpo/
# https://www.nba.com/player/1630175/cole-anthony/
# https://www.nba.com/player/1628384/og-anunoby/
# https://www.nba.com/player/1627853/ryan-arcidiacono/
# https://www.nba.com/player/1630166/deni-avdija/
# https://www.nba.com/player/1629028/deandre-ayton/
# https://www.nba.com/player/1628962/udoka-azubuike/
# https://www.nba.com/player/1630641/ibou-badji/
# https://www.nba.com/player/1628963/marvin-bagley-iii/
# https://www.nba.com/player/1641735/amari-bailey/
# https://www.nba.com/player/1631116/patrick-baldwin-jr/
# https://www.nba.com/player/1630163/lamelo-ball/
# https://www.nba.com/player/1628366/lonzo-ball/
# https://www.nba.com/player/1628964/mo-bamba/
# https://www.nba.com/player/1631094/paolo-banchero/
# https://www.nba.com/player/1630217/desmond-bane/
# https://www.nba.com/player/1630625/dalano-banton/
# https://www.nba.com/player/1631230/dominick-barlow/
# https://www.nba.com/player/203084/harrison-barnes/
# https://www.nba.com/player/1630567/scottie-barnes/
# https://www.nba.com/player/1629628/rj-barrett/
# https://www.nba.com/player/1629646/charles-bassey/
# https://www.nba.com/player/1641734/emoni-bates/
# https://www.nba.com/player/1628966/keita-bates-diop/
# https://www.nba.com/player/201587/nicolas-batum/
# https://www.nba.com/player/203078/bradley-beal/
# https://www.nba.com/player/1627736/malik-beasley/
# https://www.nba.com/player/1630699/marjon-beauchamp/
# https://www.nba.com/player/1631262/jules-bernard/
# https://www.nba.com/player/202722/davis-bertans/
# https://www.nba.com/player/201976/patrick-beverley/
# https://www.nba.com/player/1630180/saddiq-bey/
# https://www.nba.com/player/1629048/goga-bitadze/
# https://www.nba.com/player/1641931/onuralp-bitim/
# https://www.nba.com/player/202687/bismack-biyombo/
# https://www.nba.com/player/1641710/anthony-black/
# https://www.nba.com/player/1641778/leaky-black/
# https://www.nba.com/player/203992/bogdan-bogdanovic/
# https://www.nba.com/player/202711/bojan-bogdanovic/
# https://www.nba.com/player/1629626/bol-bol/
# https://www.nba.com/player/1629716/marques-bolden/
# https://www.nba.com/player/1626164/devin-booker/
# https://www.nba.com/player/1630527/brandon-boston-jr/
# https://www.nba.com/player/1628449/chris-boucher/
# https://www.nba.com/player/1630547/james-bouknight/
# https://www.nba.com/player/1631123/jamaree-bouyea/
# https://www.nba.com/player/1631103/malaki-branham/
# https://www.nba.com/player/1631128/christian-braun/
# https://www.nba.com/player/1628969/mikal-bridges/
# https://www.nba.com/player/1628970/miles-bridges/
# https://www.nba.com/player/1629052/oshae-brissett/
# https://www.nba.com/player/1627763/malcolm-brogdon/
# https://www.nba.com/player/1629717/armoni-brooks/
# https://www.nba.com/player/1628415/dillon-brooks/
# https://www.nba.com/player/1628971/bruce-brown/
# https://www.nba.com/player/1627759/jaylen-brown/
# https://www.nba.com/player/1631112/kendall-brown/
# https://www.nba.com/player/1641738/kobe-brown/
# https://www.nba.com/player/1629650/moses-brown/
# https://www.nba.com/player/1630535/greg-brown-iii/
# https://www.nba.com/player/1629718/charlie-brown-jr/
# https://www.nba.com/player/1628972/troy-brown-jr/
# https://www.nba.com/player/1628973/jalen-brunson/
# https://www.nba.com/player/1628418/thomas-bryant/
# https://www.nba.com/player/1641723/kobe-bufkin/
# https://www.nba.com/player/203493/reggie-bullock-jr/
# https://www.nba.com/player/202692/alec-burks/
# https://www.nba.com/player/1630215/jared-butler/
# https://www.nba.com/player/202710/jimmy-butler/
# https://www.nba.com/player/1631288/jamal-cain/
# https://www.nba.com/player/203484/kentavious-caldwell-pope/
# https://www.nba.com/player/1641739/toumani-camara/
# https://www.nba.com/player/1628427/vlatko-cancar/
# https://www.nba.com/player/203991/clint-capela/
# https://www.nba.com/player/1628975/jevon-carter/
# https://www.nba.com/player/1628976/wendell-carter-jr/
# https://www.nba.com/player/1627936/alex-caruso/
# https://www.nba.com/player/1630658/colin-castleton/
# https://www.nba.com/player/1630608/malcolm-cazalon/
# https://www.nba.com/player/1630577/julian-champagnie/
# https://www.nba.com/player/1631108/max-christie/
# https://www.nba.com/player/1631321/sidy-cissoko/
# https://www.nba.com/player/1641740/jaylen-clark/
# https://www.nba.com/player/1629634/brandon-clarke/
# https://www.nba.com/player/203903/jordan-clarkson/
# https://www.nba.com/player/1629651/nic-claxton/
# https://www.nba.com/player/1641730/noah-clowney/
# https://www.nba.com/player/1629599/amir-coffey/
# https://www.nba.com/player/1628381/john-collins/
# https://www.nba.com/player/1628380/zach-collins/
# https://www.nba.com/player/201144/mike-conley/
# https://www.nba.com/player/1626192/pat-connaughton/
# https://www.nba.com/player/1641731/bilal-coulibaly/
# https://www.nba.com/player/1641741/ricky-council-iv/
# https://www.nba.com/player/203496/robert-covington/
# https://www.nba.com/player/1628470/torrey-craig/
# https://www.nba.com/player/203109/jae-crowder/
# https://www.nba.com/player/1630595/cade-cunningham/
# https://www.nba.com/player/203552/seth-curry/
# https://www.nba.com/player/201939/stephen-curry/
# https://www.nba.com/player/1630700/dyson-daniels/
# https://www.nba.com/player/203076/anthony-davis/
# https://www.nba.com/player/1631098/johnny-davis/
# https://www.nba.com/player/1631120/jd-davison/
# https://www.nba.com/player/201942/demar-derozan/
# https://www.nba.com/player/1641926/dexter-dennis/
# https://www.nba.com/player/1628978/donte-divincenzo/
# https://www.nba.com/player/1631217/moussa-diabate/
# https://www.nba.com/player/1629603/mamadi-diakite/
# https://www.nba.com/player/1628977/hamidou-diallo/
# https://www.nba.com/player/1641711/gradey-dick/
# https://www.nba.com/player/1631172/ousmane-dieng/
# https://www.nba.com/player/203915/spencer-dinwiddie/
# https://www.nba.com/player/1629029/luka-doncic/
# https://www.nba.com/player/1629652/luguentz-dort/
# https://www.nba.com/player/1630245/ayo-dosunmu/
# https://www.nba.com/player/1630929/henri-drell/
# https://www.nba.com/player/203083/andre-drummond/
# https://www.nba.com/player/1630537/chris-duarte/
# https://www.nba.com/player/1630561/david-duke-jr/
# https://www.nba.com/player/1627739/kris-dunn/
# https://www.nba.com/player/201142/kevin-durant/
# https://www.nba.com/player/1631105/jalen-duren/
# https://www.nba.com/player/1631106/tari-eason/
# https://www.nba.com/player/1630162/anthony-edwards/
# https://www.nba.com/player/1630556/kessler-edwards/
# https://www.nba.com/player/1631165/keon-ellis/
# https://www.nba.com/player/203954/joel-embiid/
# https://www.nba.com/player/1629234/drew-eubanks/
# https://www.nba.com/player/203957/dante-exum/
# https://www.nba.com/player/1628981/bruno-fernando/
# https://www.nba.com/player/1627827/dorian-finney-smith/
# https://www.nba.com/player/1630201/malachi-flynn/
# https://www.nba.com/player/1631323/simone-fontecchio/
# https://www.nba.com/player/1630259/jordan-ford/
# https://www.nba.com/player/1630235/trent-forrest/
# https://www.nba.com/player/203095/evan-fournier/
# https://www.nba.com/player/1628368/deaaron-fox/
# https://www.nba.com/player/1631241/javon-freeman-liberty/
# https://www.nba.com/player/1641788/alex-fudge/
# https://www.nba.com/player/1628365/markelle-fultz/
# https://www.nba.com/player/1629655/daniel-gafford/
# https://www.nba.com/player/201568/danilo-gallinari/
# https://www.nba.com/player/1629636/darius-garland/
# https://www.nba.com/player/1630586/usman-garuba/
# https://www.nba.com/player/1630568/luka-garza/
# https://www.nba.com/player/1629232/kaiser-gates/
# https://www.nba.com/player/1641718/keyonte-george/
# https://www.nba.com/player/202331/paul-george/
# https://www.nba.com/player/201959/taj-gibson/
# https://www.nba.com/player/1630581/josh-giddey/
# https://www.nba.com/player/1628385/harry-giles-iii/
# https://www.nba.com/player/1628983/shai-gilgeous-alexander/
# https://www.nba.com/player/1630264/anthony-gill/
# https://www.nba.com/player/1631221/collin-gillespie/
# https://www.nba.com/player/1631367/jacob-gilyard/
# https://www.nba.com/player/203497/rudy-gobert/
# https://www.nba.com/player/1630692/jordan-goodwin/
# https://www.nba.com/player/203932/aaron-gordon/
# https://www.nba.com/player/201569/eric-gordon/
# https://www.nba.com/player/1628984/devonte-graham/
# https://www.nba.com/player/203924/jerami-grant/
# https://www.nba.com/player/1631260/aj-green/
# https://www.nba.com/player/201980/danny-green/
# https://www.nba.com/player/203110/draymond-green/
# https://www.nba.com/player/1630224/jalen-green/
# https://www.nba.com/player/201145/jeff-green/
# https://www.nba.com/player/1630182/josh-green/
# https://www.nba.com/player/1631100/aj-griffin/
# https://www.nba.com/player/1629656/quentin-grimes/
# https://www.nba.com/player/1631243/mouhamed-gueye/
# https://www.nba.com/player/1629060/rui-hachimura/
# https://www.nba.com/player/1630169/tyrese-haliburton/
# https://www.nba.com/player/1630181/rj-hampton/
# https://www.nba.com/player/203501/tim-hardaway-jr/
# https://www.nba.com/player/201935/james-harden/
# https://www.nba.com/player/1630702/jaden-hardy/
# https://www.nba.com/player/1631199/ron-harper-jr/
# https://www.nba.com/player/203914/gary-harris/
# https://www.nba.com/player/203925/joe-harris/
# https://www.nba.com/player/1630284/kevon-harris/
# https://www.nba.com/player/202699/tobias-harris/
# https://www.nba.com/player/1627885/shaquille-harrison/
# https://www.nba.com/player/1628404/josh-hart/
# https://www.nba.com/player/1628392/isaiah-hartenstein/
# https://www.nba.com/player/1630573/sam-hauser/
# https://www.nba.com/player/1641722/jordan-hawkins/
# https://www.nba.com/player/1629637/jaxson-hayes/
# https://www.nba.com/player/1630165/killian-hayes/
# https://www.nba.com/player/202330/gordon-hayward/
# https://www.nba.com/player/1630703/scoot-henderson/
# https://www.nba.com/player/1641707/taylor-hendricks/
# https://www.nba.com/player/1629639/tyler-herro/
# https://www.nba.com/player/1627741/buddy-hield/
# https://www.nba.com/player/1629312/haywood-highsmith/
# https://www.nba.com/player/1630207/nate-hinton/
# https://www.nba.com/player/1641793/dmoi-hodge/
# https://www.nba.com/player/1628988/aaron-holiday/
# https://www.nba.com/player/201950/jrue-holiday/
# https://www.nba.com/player/203200/justin-holiday/
# https://www.nba.com/player/1626158/richaun-holmes/
# https://www.nba.com/player/1631096/chet-holmgren/
# https://www.nba.com/player/1641720/jalen-hood-schifino/
# https://www.nba.com/player/201143/al-horford/
# https://www.nba.com/player/1629659/talen-horton-tucker/
# https://www.nba.com/player/1627863/danuel-house-jr/
# https://www.nba.com/player/1631216/caleb-houstan/
# https://www.nba.com/player/1641724/jett-howard/
# https://www.nba.com/player/1628989/kevin-huerter/
# https://www.nba.com/player/1630643/jay-huff/
# https://www.nba.com/player/1629631/deandre-hunter/
# https://www.nba.com/player/1630538/bones-hyland/
# https://www.nba.com/player/204060/joe-ingles/
# https://www.nba.com/player/1627742/brandon-ingram/
# https://www.nba.com/player/202681/kyrie-irving/
# https://www.nba.com/player/1628371/jonathan-isaac/
# https://www.nba.com/player/1631093/jaden-ivey/
# https://www.nba.com/player/1641713/gg-jackson/
# https://www.nba.com/player/1630543/isaiah-jackson/
# https://www.nba.com/player/202704/reggie-jackson/
# https://www.nba.com/player/1641748/andre-jackson-jr/
# https://www.nba.com/player/1628991/jaren-jackson-jr/
# https://www.nba.com/player/1631218/trayce-jackson-davis/
# https://www.nba.com/player/2544/lebron-james/
# https://www.nba.com/player/1631170/jaime-jaquez-jr/
# https://www.nba.com/player/1629610/daquan-jeffries/
# https://www.nba.com/player/1629660/ty-jerome/
# https://www.nba.com/player/1630198/isaiah-joe/
# https://www.nba.com/player/1629661/cameron-johnson/
# https://www.nba.com/player/1630552/jalen-johnson/
# https://www.nba.com/player/201949/james-johnson/
# https://www.nba.com/player/1629640/keldon-johnson/
# https://www.nba.com/player/1630553/keon-johnson/
# https://www.nba.com/player/1641749/keyontae-johnson/
# https://www.nba.com/player/203999/nikola-jokic/
# https://www.nba.com/player/1641732/colby-jones/
# https://www.nba.com/player/1627745/damian-jones/
# https://www.nba.com/player/1630529/herbert-jones/
# https://www.nba.com/player/1630200/tre-jones/
# https://www.nba.com/player/1626145/tyus-jones/
# https://www.nba.com/player/1627884/derrick-jones-jr/
# https://www.nba.com/player/201599/deandre-jordan/
# https://www.nba.com/player/202709/cory-joseph/
# https://www.nba.com/player/1631107/nikola-jovic/
# https://www.nba.com/player/1630548/johnny-juzang/
# https://www.nba.com/player/1628379/luke-kennard/
# https://www.nba.com/player/1631117/walker-kessler/
# https://www.nba.com/player/1630296/braxton-key/
# https://www.nba.com/player/1630557/corey-kispert/
# https://www.nba.com/player/1628467/maxi-kleber/
# https://www.nba.com/player/1628995/kevin-knox-ii/
# https://www.nba.com/player/1631132/christian-koloko/
# https://www.nba.com/player/1629723/john-konchar/
# https://www.nba.com/player/1627788/furkan-korkmaz/
# https://www.nba.com/player/1628436/luke-kornet/
# https://www.nba.com/player/1630249/vit-krejci/
# https://www.nba.com/player/1630228/jonathan-kuminga/
# https://www.nba.com/player/1628398/kyle-kuzma/
# https://www.nba.com/player/1631222/jake-laravia/
# https://www.nba.com/player/203897/zach-lavine/
# https://www.nba.com/player/1629111/jock-landale/
# https://www.nba.com/player/1630639/aj-lawson/
# https://www.nba.com/player/1627747/caris-levert/
# https://www.nba.com/player/1627814/damion-lee/
# https://www.nba.com/player/1630240/saben-lee/
# https://www.nba.com/player/203458/alex-len/
# https://www.nba.com/player/202695/kawhi-leonard/
# https://www.nba.com/player/1641721/maxwell-lewis/
# https://www.nba.com/player/1630184/kira-lewis-jr/
# https://www.nba.com/player/1630604/ej-liddell/
# https://www.nba.com/player/203081/damian-lillard/
# https://www.nba.com/player/1629642/nassir-little/
# https://www.nba.com/player/1641726/dereck-lively-ii/
# https://www.nba.com/player/1630587/isaiah-livers/
# https://www.nba.com/player/1641753/chris-livingston/
# https://www.nba.com/player/1631254/kenneth-lofton-jr/
# https://www.nba.com/player/1626172/kevon-looney/
# https://www.nba.com/player/201572/brook-lopez/
# https://www.nba.com/player/201577/robin-lopez/
# https://www.nba.com/player/201567/kevin-love/
# https://www.nba.com/player/200768/kyle-lowry/
# https://www.nba.com/player/1641754/seth-lundy/
# https://www.nba.com/player/1626168/trey-lyles/
# https://www.nba.com/player/1630177/theo-maledon/
# https://www.nba.com/player/1630572/sandro-mamukelashvili/
# https://www.nba.com/player/1629611/terance-mann/
# https://www.nba.com/player/1630544/tre-mann/
# https://www.nba.com/player/1626246/boban-marjanovic/
# https://www.nba.com/player/1628374/lauri-markkanen/
# https://www.nba.com/player/1630230/naji-marshall/
# https://www.nba.com/player/1628997/caleb-martin/
# https://www.nba.com/player/1628998/cody-martin/
# https://www.nba.com/player/1630231/kj-martin/
# https://www.nba.com/player/1629726/garrison-mathews/
# https://www.nba.com/player/1631097/bennedict-mathurin/
# https://www.nba.com/player/202083/wesley-matthews/
# https://www.nba.com/player/1630178/tyrese-maxey/
# https://www.nba.com/player/1630219/skylar-mays/
# https://www.nba.com/player/1630540/miles-mcbride/
# https://www.nba.com/player/203468/cj-mccollum/
# https://www.nba.com/player/204456/tj-mcconnell/
# https://www.nba.com/player/1630183/jaden-mcdaniels/
# https://www.nba.com/player/1629667/jalen-mcdaniels/
# https://www.nba.com/player/203926/doug-mcdermott/
# https://www.nba.com/player/201580/javale-mcgee/
# https://www.nba.com/player/1631121/bryce-mcgowens/
# https://www.nba.com/player/1629162/jordan-mclaughlin/
# https://www.nba.com/player/1629001/deanthony-melton/
# https://www.nba.com/player/1641877/nathan-mensah/
# https://www.nba.com/player/1630241/sam-merrill/
# https://www.nba.com/player/1629002/chimezie-metu/
# https://www.nba.com/player/203995/vasilije-micic/
# https://www.nba.com/player/203114/khris-middleton/
# https://www.nba.com/player/1641706/brandon-miller/
# https://www.nba.com/player/1641757/jordan-miller/
# https://www.nba.com/player/1631159/leonard-miller/
# https://www.nba.com/player/201988/patty-mills/
# https://www.nba.com/player/1629003/shake-milton/
# https://www.nba.com/player/1631303/justin-minaya/
# https://www.nba.com/player/1631169/josh-minott/
# https://www.nba.com/player/1630558/davion-mitchell/
# https://www.nba.com/player/1628378/donovan-mitchell/
# https://www.nba.com/player/1630596/evan-mobley/
# https://www.nba.com/player/1630600/isaiah-mobley/
# https://www.nba.com/player/1628370/malik-monk/
# https://www.nba.com/player/1630541/moses-moody/
# https://www.nba.com/player/1629875/xavier-moon/
# https://www.nba.com/player/1631111/wendell-moore-jr/
# https://www.nba.com/player/1629630/ja-morant/
# https://www.nba.com/player/202693/markieff-morris/
# https://www.nba.com/player/1628420/monte-morris/
# https://www.nba.com/player/202694/marcus-morris-sr/
# https://www.nba.com/player/1630530/trey-murphy-iii/
# https://www.nba.com/player/1627749/dejounte-murray/
# https://www.nba.com/player/1627750/jamal-murray/
# https://www.nba.com/player/1631099/keegan-murray/
# https://www.nba.com/player/1631200/kris-murray/
# https://www.nba.com/player/203488/mike-muscala/
# https://www.nba.com/player/1629004/svi-mykhailiuk/
# https://www.nba.com/player/1626204/larry-nance-jr/
# https://www.nba.com/player/1629614/andrew-nembhard/
# https://www.nba.com/player/1630174/aaron-nesmith/
# https://www.nba.com/player/1627777/georges-niang/
# https://www.nba.com/player/1630227/daishen-nix/
# https://www.nba.com/player/1630192/zeke-nnaji/
# https://www.nba.com/player/1629669/jaylen-nowell/
# https://www.nba.com/player/1641806/markquis-nowell/
# https://www.nba.com/player/1628373/frank-ntilikina/
# https://www.nba.com/player/203994/jusuf-nurkic/
# https://www.nba.com/player/1629670/jordan-nwora/
# https://www.nba.com/player/1626220/royce-oneale/
# https://www.nba.com/player/1629643/chuma-okeke/
# https://www.nba.com/player/1629006/josh-okogie/
# https://www.nba.com/player/1630168/onyeka-okongwu/
# https://www.nba.com/player/1630171/isaac-okoro/
# https://www.nba.com/player/203506/victor-oladipo/
# https://www.nba.com/player/203482/kelly-olynyk/
# https://www.nba.com/player/1630647/eugene-omoruyi/
# https://www.nba.com/player/1626224/cedi-osman/
# https://www.nba.com/player/1626162/kelly-oubre-jr/
# https://www.nba.com/player/101108/chris-paul/
# https://www.nba.com/player/1626166/cameron-payne/
# https://www.nba.com/player/1627780/gary-payton-ii/
# https://www.nba.com/player/1641809/drew-peterson/
# https://www.nba.com/player/1630196/filip-petrusev/
# https://www.nba.com/player/1641763/julian-phillips/
# https://www.nba.com/player/1629618/jalen-pickett/
# https://www.nba.com/player/203486/mason-plumlee/
# https://www.nba.com/player/1641764/brandin-podziemski/
# https://www.nba.com/player/1627751/jakob-poeltl/
# https://www.nba.com/player/1630197/aleksej-pokusevski/
# https://www.nba.com/player/1629673/jordan-poole/
# https://www.nba.com/player/1629007/jontay-porter/
# https://www.nba.com/player/1641854/craig-porter-jr/
# https://www.nba.com/player/1629008/michael-porter-jr/
# https://www.nba.com/player/203490/otto-porter-jr/
# https://www.nba.com/player/1626171/bobby-portis/
# https://www.nba.com/player/204001/kristaps-porzingis/
# https://www.nba.com/player/1630695/micah-potter/
# https://www.nba.com/player/203939/dwight-powell/
# https://www.nba.com/player/1626181/norman-powell/
# https://www.nba.com/player/1630554/jason-preston/
# https://www.nba.com/player/1630563/joshua-primo/
# https://www.nba.com/player/1627752/taurean-prince/
# https://www.nba.com/player/1630202/payton-pritchard/
# https://www.nba.com/player/1641765/olivier-maxence-prosper/
# https://www.nba.com/player/1630243/trevelin-queen/
# https://www.nba.com/player/1629674/neemias-queta/
# https://www.nba.com/player/1630193/immanuel-quickley/
# https://www.nba.com/player/1631311/lester-quinones/
# https://www.nba.com/player/203944/julius-randle/
# https://www.nba.com/player/1641871/duop-reath/
# https://www.nba.com/player/1630559/austin-reaves/
# https://www.nba.com/player/1629629/cam-reddish/
# https://www.nba.com/player/1630194/paul-reed/
# https://www.nba.com/player/1629675/naz-reid/
# https://www.nba.com/player/1631197/jared-rhoden/
# https://www.nba.com/player/1630208/nick-richards/
# https://www.nba.com/player/1626196/josh-richardson/
# https://www.nba.com/player/1629130/duncan-robinson/
# https://www.nba.com/player/1629010/jerome-robinson/
# https://www.nba.com/player/1629011/mitchell-robinson/
# https://www.nba.com/player/1631115/orlando-robinson/
# https://www.nba.com/player/1630526/jeremiah-robinson-earl/
# https://www.nba.com/player/1631223/david-roddy/
# https://www.nba.com/player/1631157/ryan-rollins/
# https://www.nba.com/player/201565/derrick-rose/
# https://www.nba.com/player/1626179/terry-rozier/
# https://www.nba.com/player/1641712/rayan-rupert/
# https://www.nba.com/player/1626156/dangelo-russell/
# https://www.nba.com/player/1630346/matt-ryan/
# https://www.nba.com/player/1627734/domantas-sabonis/
# https://www.nba.com/player/1629677/luka-samanic/
# https://www.nba.com/player/1631257/jermaine-samuels-jr/
# https://www.nba.com/player/1641766/adama-sanogo/
# https://www.nba.com/player/1630611/gui-santos/
# https://www.nba.com/player/203967/dario-saric/
# https://www.nba.com/player/1630846/olivier-sarr/
# https://www.nba.com/player/1631204/marcus-sasser/
# https://www.nba.com/player/1629678/admiral-schofield/
# https://www.nba.com/player/203471/dennis-schroder/
# https://www.nba.com/player/1631220/dereon-seabron/
# https://www.nba.com/player/1630578/alperen-sengun/
# https://www.nba.com/player/1641729/brice-sensabaugh/
# https://www.nba.com/player/1629012/collin-sexton/
# https://www.nba.com/player/1629013/landry-shamet/
# https://www.nba.com/player/1630549/dayron-sharpe/
# https://www.nba.com/player/1631101/shaedon-sharpe/
# https://www.nba.com/player/1641767/ben-sheppard/
# https://www.nba.com/player/1627783/pascal-siakam/
# https://www.nba.com/player/1627732/ben-simmons/
# https://www.nba.com/player/1629014/anfernee-simons/
# https://www.nba.com/player/1630579/jericho-sims/
# https://www.nba.com/player/1631376/dmytro-skapintsev/
# https://www.nba.com/player/1641771/jalen-slawson/
# https://www.nba.com/player/1630606/javonte-smart/
# https://www.nba.com/player/203935/marcus-smart/
# https://www.nba.com/player/1630696/dru-smith/
# https://www.nba.com/player/202397/ish-smith/
# https://www.nba.com/player/1630188/jalen-smith/
# https://www.nba.com/player/1631173/terquavion-smith/
# https://www.nba.com/player/1628372/dennis-smith-jr/
# https://www.nba.com/player/1631095/jabari-smith-jr/
# https://www.nba.com/player/1641733/nick-smith-jr/
# https://www.nba.com/player/1631110/jeremy-sochan/
# https://www.nba.com/player/1630531/jaden-springer/
# https://www.nba.com/player/1630205/lamar-stevens/
# https://www.nba.com/player/1630191/isaiah-stewart/
# https://www.nba.com/player/1631124/julian-strawther/
# https://www.nba.com/player/1629622/max-strus/
# https://www.nba.com/player/1630591/jalen-suggs/
# https://www.nba.com/player/1631306/cole-swider/
# https://www.nba.com/player/1630256/jaesean-tate/
# https://www.nba.com/player/1628369/jayson-tatum/
# https://www.nba.com/player/1630678/terry-taylor/
# https://www.nba.com/player/202066/garrett-temple/
# https://www.nba.com/player/1631207/dalen-terry/
# https://www.nba.com/player/1628464/daniel-theis/
# https://www.nba.com/player/1630560/cam-thomas/
# https://www.nba.com/player/1641708/amen-thompson/
# https://www.nba.com/player/1641709/ausar-thompson/
# https://www.nba.com/player/202691/klay-thompson/
# https://www.nba.com/player/202684/tristan-thompson/
# https://www.nba.com/player/1630550/jt-thor/
# https://www.nba.com/player/1629680/matisse-thybulle/
# https://www.nba.com/player/1630214/xavier-tillman/
# https://www.nba.com/player/1631210/jacob-toppin/
# https://www.nba.com/player/1630167/obi-toppin/
# https://www.nba.com/player/1629308/juan-toscano-anderson/
# https://www.nba.com/player/1626157/karl-anthony-towns/
# https://www.nba.com/player/1629018/gary-trent-jr/
# https://www.nba.com/player/1631131/oscar-tshiebwe/
# https://www.nba.com/player/200782/pj-tucker/
# https://www.nba.com/player/1626167/myles-turner/
# https://www.nba.com/player/1641816/hunter-tyson/
# https://www.nba.com/player/1630649/stanley-umude/
# https://www.nba.com/player/202685/jonas-valanciunas/
# https://www.nba.com/player/1627832/fred-vanvleet/
# https://www.nba.com/player/1629020/jarred-vanderbilt/
# https://www.nba.com/player/1630170/devin-vassell/
# https://www.nba.com/player/1628426/sasha-vezenkov/
# https://www.nba.com/player/1629216/gabe-vincent/
# https://www.nba.com/player/202696/nikola-vucevic/
# https://www.nba.com/player/1629731/dean-wade/
# https://www.nba.com/player/1630532/franz-wagner/
# https://www.nba.com/player/1629021/moritz-wagner/
# https://www.nba.com/player/1630688/ish-wainright/
# https://www.nba.com/player/1631133/jabari-walker/
# https://www.nba.com/player/1641716/jarace-walker/
# https://www.nba.com/player/1629022/lonnie-walker-iv/
# https://www.nba.com/player/1641717/cason-wallace/
# https://www.nba.com/player/1641775/jordan-walsh/
# https://www.nba.com/player/1629023/pj-washington/
# https://www.nba.com/player/1630613/duane-washington-jr/
# https://www.nba.com/player/1631102/tyty-washington-jr/
# https://www.nba.com/player/1629139/yuta-watanabe/
# https://www.nba.com/player/1630322/lindy-waters-iii/
# https://www.nba.com/player/1630570/trendon-watford/
# https://www.nba.com/player/1631212/peyton-watson/
# https://www.nba.com/player/1641705/victor-wembanyama/
# https://www.nba.com/player/1631104/blake-wesley/
# https://www.nba.com/player/201566/russell-westbrook/
# https://www.nba.com/player/1629632/coby-white/
# https://www.nba.com/player/1628401/derrick-white/
# https://www.nba.com/player/1641727/dariq-whitehead/
# https://www.nba.com/player/1641715/cam-whitmore/
# https://www.nba.com/player/1630598/aaron-wiggins/
# https://www.nba.com/player/203952/andrew-wiggins/
# https://www.nba.com/player/1629623/lindell-wigginton/
# https://www.nba.com/player/1630314/brandon-williams/
# https://www.nba.com/player/1629684/grant-williams/
# https://www.nba.com/player/1631114/jalen-williams/
# https://www.nba.com/player/1631119/jaylin-williams/
# https://www.nba.com/player/1629026/kenrich-williams/
# https://www.nba.com/player/1631109/mark-williams/
# https://www.nba.com/player/1631466/nate-williams/
# https://www.nba.com/player/1630172/patrick-williams/
# https://www.nba.com/player/1630533/ziaire-williams/
# https://www.nba.com/player/1629057/robert-williams-iii/
# https://www.nba.com/player/1631246/vince-williams-jr/
# https://www.nba.com/player/1629627/zion-williamson/
# https://www.nba.com/player/1630592/jalen-wilson/
# https://www.nba.com/player/1629685/dylan-windler/
# https://www.nba.com/player/1630164/james-wiseman/
# https://www.nba.com/player/1631209/isaiah-wong/
# https://www.nba.com/player/1626174/christian-wood/
# https://www.nba.com/player/1626153/delon-wright/
# https://www.nba.com/player/201152/thaddeus-young/
# https://www.nba.com/player/1629027/trae-young/
# https://www.nba.com/player/1630209/omer-yurtseven/
# https://www.nba.com/player/203469/cody-zeller/
# https://www.nba.com/player/1627826/ivica-zubac/

# %%
df_jugadores = pd.DataFrame({
    "id_jugador": id_jugador,
    "Nombre": nombre,
    "Apellido": apellido,
    "Equipo": equipo,
    "Dorsal": dorsal,
    "Posición": posicion,
    "PPG": ppg,
    "RPG": rpg,
    "APG": apg,
    "PIE": pie,
    "Altura": altura,
    "Peso": peso,
    "País": pais,
    "Último Equipo": ultimo_equipo,
    "Edad": edad,
    "Cumpleaños": cumpleaños,
    "Draft": draft,
    "Experiencia": experiencia
})

# %%
# Me he dado cuenta que igual hacemos el proceso 3-4 veces para ir actualizando datos o por si hay algún
# dato que a través de bs4 no se hay aimportado bien. Entonces se me ha ocurrido que no sobreescriba el archivo si
# ya existe, y así luego con pandas, podemos hacer actualización de archivos o alguna cosa de esas
# Para ello se puede hacer lo del contador que ya he utilizado en otro sitio para generar nombres de excel


def guardar_excel_con_numeracion(df, directorio, nombre_base):
    directorio = os.path.join(os.getcwd(), "excels")

    # Si no existe el directorio con esto lo creará
    if not os.path.exists(directorio):
        os.makedirs(directorio)

    ruta_base = os.path.join(directorio, nombre_base)
    contador = 0
    ruta_final = f"{ruta_base}.xlsx"

    while os.path.exists(ruta_final):
        contador += 1
        ruta_final = f"{ruta_base}_{contador}.xlsx"

    df.to_excel(ruta_final, index=False, engine='openpyxl')
    print(f"Archivo guardado como: {ruta_final}")

guardar_excel_con_numeracion(df_jugadores, "excels", "jugadores_nba")
# Out:
# Archivo guardado como: c:\Users\34670\Desktop\python\Hack a boss\proyecto_1\excels\jugadores_nba_4.xlsx

# %%
def llamando_web_nba_jugadores():
    # Iniciar el navegador
    browser = webdriver.Chrome()

    # Navegar a la página
    browser.get("https://nba.com/games")
    browser.maximize_window()

    # Aceptar la política de cookies
    sleep(1)
    browser.find_element(by=By.ID, value="onetrust-accept-btn-handler").click()

    # Navegar a la página de jugadores
    sleep(2)
    browser.find_element(by=By.XPATH, value="//span[contains(text(), 'Players')]").click()

    # Seleccionar para mostrar todos los jugadores
    sleep(0.3)
    seleccion_menu = browser.find_element(by=By.CSS_SELECTOR, value=".DropDown_select__4pIg9")
    seleccion_menu.click()
    seleccion_menu_all = browser.find_element(by=By.CSS_SELECTOR, value="#__next > div.Layout_base__6IeUC.Layout_justNav__2H4H0.Layout_withSubNav__ByKRF > div.Layout_mainContent__jXliI > main > div.MaxWidthContainer_mwc__ID5AG > section > div > div.PlayerList_content__kwT7z > div.PlayerList_filters__n_6IL > div.PlayerList_pagination__c5ijE > div > div.Pagination_pageDropdown__KgjBU > div > label > div > select > option:nth-child(1)").click()

    # Esperar a que la lista de jugadores se cargue
    sleep(2)

       # Ahora ya tenemos listado 542 filas. Vamos a empezar con el webscreaping
    # Lo primero que tenemos que hacer es darle a bs4 la página que quiere hacer scraping, para ello vamos a preguntar a selenium cual es el html:

    web_jugadores = browser.page_source

    # A partir de ahí vamos con bs4

    soup = BeautifulSoup(web_jugadores, "html.parser")

    # Y ahora vamos a buscar todos los enlaces que hay en la página de los jugadores. Para ello utilizamos un bucle con la clase Anchor... para guardarlos en una variable

    urls_jugadores_nba = [a["href"] for a in soup.find_all("a", class_="Anchor_anchor__cSc3P RosterRow_playerLink__qw1vG")]
    
    return web_jugadores

# Ahora puedes llamar a la función
web_jugadores = llamando_web_nba_jugadores()
